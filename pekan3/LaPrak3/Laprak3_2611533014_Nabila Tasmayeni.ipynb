# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“OPERATOR PYTHON”**
#
# **Disusun Oleh :**
#
# **Nabila Tasmayeni**
#
# **2611533014**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **SHERLY SUKMADIRA**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Tuhan Yang Maha Esa karena atas rahmat dan karunia-Nya, penulis dapat menyelesaikan laporan praktikum yang berjudul “Operator Python” dengan baik.
#
# Laporan ini dibuat untuk memenuhi tugas praktikum serta menambah pemahaman tentang penggunaan operator dalam bahasa pemrograman Python. Dalam laporan ini membahas enam jenis operator, yaitu operator aritmatika, operator perbandingan, operator logika, operator assignment, operator lainnya, dan operator bitwise. Melalui praktikum ini, penulis dapat memahami fungsi dan penggunaan masing-masing operator dalam membuat suatu program Python.
#
# Penulis menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, penulis mengharapkan kritik dan saran yang membangun untuk memperbaiki laporan ini. Semoga laporan ini dapat bermanfaat dan membantu pembaca dalam memahami penggunaan operator pada Python.
#
#
#
#
# <div align ="right">
# Padang,2026
# <br><br><br>
# Nabila Tasmayeni
# <br>
# 2611533014
# </div>

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam pemrograman, operator merupakan salah satu bagian penting yang digunakan untuk mengolah data dan menjalankan berbagai operasi di dalam sebuah program. Kita dapat melakukan perhitungan, membandingkan nilai, menentukan kondisi, memberikan nilai pada variabel, serta melakukan operasi lainnya sesuai kebutuhan program.
#
# Python memiliki berbagai jenis operator, Beberapa operator yang digunakan dalam Python yaitu operator aritmatika, operator perbandingan, operator logika, operator assignment, operator lainnya, dan operator bitwise. Setiap operator memiliki fungsi yang berbeda. Operator aritmatika digunakan untuk melakukan perhitungan, operator perbandingan digunakan untuk membandingkan nilai, operator logika digunakan untuk menggabungkan atau menentukan kondisi tertentu, operator assignment yang digunakan untuk memberikan atau mengubah nilai pada variabel, operator lainnya digunakan untuk kebutuhan operasi tertentu dalam Python, serta operator bitwise yang digunakan untuk melakukan operasi pada bilangan dalam bentuk bit. Dengan memahami berbagai jenis operator tersebut, kita dapat lebih mudah membuat program dan memahami bagaimana suatu data diproses oleh Python.
#
#
# ## 1.2 Tujuan
# 1. Mengetahui pengertian dan fungsi operator dalam bahasa pemrograman Python.
# 2. Memahami penggunaan operator aritmatika, perbandingan, logika, assignment, lainnya, dan bitwise.
# 3. Mengetahui perbedaan fungsi dari setiap jenis operator pada Python.
# 4. Mampu menggunakan berbagai operator tersebut dalam program Python sederhana.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman tentang penggunaan operator dalam bahasa pemrograman Python.
# 2. Mengetahui fungsi dari operator aritmatika, perbandingan, logika, assignment, lainnya, dan bitwise.
# 3. Membantu memahami cara kerja operator saat digunakan dalam sebuah program.
# 4. Melatih kemampuan dalam menggunakan berbagai operator untuk membuat program sederhana.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Operator dalam Python adalah simbol atau tanda yang digunakan untuk melakukan operasi terhadap suatu nilai atau variabel. Operator membantu program dalam melakukan perhitungan, membandingkan nilai, menentukan kondisi, memberikan nilai, dan melakukan operasi lainnya. Penggunaan operator merupakan salah satu dasar penting yang perlu dipahami dalam membuat program Python.
#
# 1. Operator Aritmatika
#
# Operator aritmatika digunakan untuk melakukan operasi perhitungan matematika. Operator ini sering digunakan dalam program untuk menghitung suatu nilai.
# Beberapa operator aritmatika dalam Python yaitu:
# ```text
# + : penjumlahan
# - : pengurangan
# * : perkalian
# / : pembagian
# % : sisa pembagian (modulus)
# // : pembagian bulat
# ** : perpangkatan
# ```
#
# 2. Operator Perbandingan
#
# Operator perbandingan digunakan untuk membandingkan dua nilai. Hasil dari perbandingan biasanya berupa True atau False.
# Beberapa operator perbandingan yaitu:
# ```text
# == : sama dengan
# != : tidak sama dengan
# > : lebih besar
# < : lebih kecil
# >= : lebih besar atau sama dengan
# <= : lebih kecil atau sama dengan
# ```
#
# 3. Operator Logika
#
# Operator logika digunakan untuk menggabungkan atau memeriksa beberapa kondisi. Operator ini biasanya digunakan bersama dengan nilai boolean, yaitu True dan False.
# Operator logika dalam Python terdiri dari:
# ```text
# and : menghasilkan True jika kedua kondisi benar.
# or : menghasilkan True jika salah satu kondisi benar.
# not : membalik hasil kondisi, dari True menjadi False atau sebaliknya.
# ```
#
# 4. Operator Assignment
#
# Operator assignment digunakan untuk memberikan nilai ke sebuah variabel atau mengubah nilai variabel. Operator yang paling dasar adalah =.
# Contohnya:
# x = 10
# Selain =, terdapat beberapa operator assignment lainnya, seperti:
# ```text
# += : menambahkan nilai
# -= : mengurangi nilai
# *= : mengalikan nilai
# /= : membagi nilai
# %= : menyimpan sisa pembagian
# ```
#
# 5. Operator Lainnya
#
# Operator lainnya digunakan untuk melakukan operasi tertentu yang tidak termasuk dalam operator aritmatika, perbandingan, logika, assignment, dan bitwise. Operator ini dapat membantu dalam memeriksa suatu objek atau mengetahui apakah suatu nilai terdapat dalam sebuah data.
# Contohnya adalah:
# ```text
# is : memeriksa apakah dua objek merupakan objek yang sama.
# is not : memeriksa apakah dua objek bukan objek yang sama.
# in : memeriksa apakah suatu nilai terdapat dalam data.
# not in : memeriksa apakah suatu nilai tidak terdapat dalam data.
# ```
#
# 6. Operator Bitwise
#
# Operator bitwise digunakan untuk melakukan operasi pada bilangan berdasarkan bentuk bit atau bilangan biner. Operator ini biasanya digunakan pada operasi yang berhubungan dengan pengolahan data pada tingkat bit.
# Beberapa operator bitwise dalam Python yaitu:
# ```text
# & : AND
# | : OR
# ^ : XOR
# ~ : NOT
# << : geser bit ke kiri
# >> : geser bit ke kanan
# ```
#
# Dengan memahami berbagai jenis operator tersebut, kita dapat mengetahui bagaimana Python mengolah nilai dan menjalankan suatu perintah. Pemahaman tentang operator juga menjadi dasar untuk membuat program yang lebih terstruktur dan sesuai dengan kebutuhan.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Aritmatika_2611533013.py"

# %%
#Buat file dengan nama aritmatika_NIM.py
#Buat program untuk operator aritmatika dalam Python
#Nma variabel ditambah 4 digit nim terakhir contoh :angka_1234
#Program ini menggunakan fungsi input()
#Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_3014 = int(input("Input angka-1="))
angka2_3014 = int(input("Input angka-2="))

# Penjumlahan
hasil_3014 =angka1_3014 + angka2_3014
print("\nOperator Penjumlahan")
print("Hasil =", hasil_3014)

#Pengurangan
hasil_3014 = angka1_3014 - angka2_3014
print("\nOperator Pengurangan")
print("Hasil =", hasil_3014)

#Perkalian
hasil_3014 = angka1_3014 * angka2_3014
print("\nOperator Perkalian")
print("Hasil =", hasil_3014)

#Pembagian, pembagian bulat, dan sisa bagi
if angka2_3014 != 0:
    hasil_3014 = angka1_3014 / angka2_3014
    print("\nOperator Pembagian")
    print("Hasil =", hasil_3014)

    hasil_3014 = angka1_3014 // angka2_3014
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_3014)

    hasil_3014 = angka1_3014 % angka2_3014
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_3014)
else:
    print("Angka kedua tidak bole bernilai 0,")

# Pangkat
hasil_3014 = angka1_3014 ** angka2_3014
print("\nOperator Pangkat")
print("Hasil =", hasil_3014)
# Out:
# Operator Penjumlahan
# Hasil = 3
#
# Operator Pengurangan
# Hasil = -1
#
# Operator Perkalian
# Hasil = 2
#
# Operator Pembagian
# Hasil = 0.5
#
# Operator Pembagian Bulat
# Hasil = 0
#
# Operator Sisa Bagi
# Hasil = 1
#
# Operator Pangkat
# Hasil = 1

# %% [markdown]
# **Penjelasan :**
# 1. Program meminta pengguna memasukkan dua angka menggunakan fungsi input().
# 2. Nilai yang dimasukkan diubah menjadi tipe data integer menggunakan int().
# 3. Variabel yang digunakan adalah angka1_3014 dan angka2_3014.
# 4. Jika dimasukkan angka1_3014 = 1 dan angka2_3014 = 2, maka hasil operasinya:
# Penjumlahan (+) → 1 + 2 = 3
# Pengurangan (-) → 1 - 2 = -1
# Perkalian (*) → 1 × 2 = 2
# Pembagian (/) → 1 / 2 = 0.5
# Pembagian bulat (//) → 1 // 2 = 0
# Sisa bagi (%) → 1 % 2 = 1
# Pangkat (**) → 1 ** 2 = 1
# 5. Bagian if angka2_3014 != 0 digunakan untuk memastikan angka kedua tidak bernilai 0 sebelum melakukan operasi pembagian.
# 6. Dari program ini dapat diketahui bahwa setiap operator aritmatika memiliki fungsi yang berbeda dalam mengolah angka.

# %% [markdown]
# ### 2.2.2 Program "perbandingan_2611533014.py"

# %%
#Buat file dengan nama perbandingan_NIM.py
#Nama variabel ditambah 4 digit nim terakhir contoh : angka_1234
#Program ini menggunakan fungsi input()
#Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
#Program operator perbandingan dalam Python

angka1_3014 = int(input("Input-angka-1: "))
angka2_3014 = int(input("Input-angka-2: "))

#Lebih besar dari
hasil_3014 = angka1_3014 > angka2_3014
print("\nOperator Lebih besar dari")
print("angka1_3014 > angka2_3014 =", hasil_3014)

#Lebih kecil dari
hasil_3014 = angka1_3014 < angka2_3014
print("\nOperator Lebih kecil dari")
print("angka1_3014 < angka2_3014 =", hasil_3014)

#Lebih besar dari atau sama dengan
hasil_3014 = angka1_3014 >= angka2_3014
print("\nOperator Lebih besar dari atau sama dengan")
print("angka1_3014 >= angka2_3014 =", hasil_3014)

#Lebih kecil dari atau sama dengan
hasil_3014 = angka1_3014 <= angka2_3014
print("\nOperator Lebih kecil dari atau sama dengan")
print("angka1_3014 <= angka2_3014 =", hasil_3014)

#sama dengan
hasil_3014 = angka1_3014 == angka2_3014
print("\nOperator sama dengan")
print("angka1_3014 == angka2_3014 =", hasil_3014)

#Tidak sama dengan
hasil_3014 = angka1_3014 != angka2_3014
print("\nOperator Tidak sama dengan")
print("angka1_3014 != angka2_3014 =", hasil_3014)

#Tambahan: perbandingan berantai dalam Python
hasil_3014 = 0 < angka1_3014 < 100
print("\nOperator Perbandingan Berantai")
print("0 < angka1_3014 < 100 =", hasil_3014)

hasil_3014 = 0 < angka2_3014 < 100
print("0 < angka2_3014 < 100 =", hasil_3014)
# Out:
# Operator Lebih besar dari
# angka1_3014 > angka2_3014 = False
#
# Operator Lebih kecil dari
# angka1_3014 < angka2_3014 = True
#
# Operator Lebih besar dari atau sama dengan
# angka1_3014 >= angka2_3014 = False
#
# Operator Lebih kecil dari atau sama dengan
# angka1_3014 <= angka2_3014 = True
#
# Operator sama dengan
# angka1_3014 == angka2_3014 = False
#
# Operator Tidak sama dengan
# angka1_3014 != angka2_3014 = True
#
# Operator Perbandingan Berantai
# 0 < angka1_3014 < 100 = True
# 0 < angka2_3014 < 100 = True

# %% [markdown]
# **Penjelasan:**
# 1. Program meminta pengguna memasukkan dua angka menggunakan fungsi input().
# 2. Nilai yang dimasukkan diubah menjadi tipe data integer menggunakan int().
# 3. Pada percobaan ini, nilai yang dimasukkan adalah:
# angka1 = 10
# angka2 = 20
# 4. Operator lebih besar (>) membandingkan apakah 10 lebih besar dari 20. Hasilnya False.
# 5. Operator lebih kecil (<) membandingkan apakah 10 lebih kecil dari 20. Hasilnya True.
# 6. Operator lebih besar atau sama dengan (>=) membandingkan apakah 10 lebih besar atau sama dengan 20. Hasilnya False.
# 7. Operator lebih kecil atau sama dengan (<=) membandingkan apakah 10 lebih kecil atau sama dengan 20. Hasilnya True.
# 8. Operator sama dengan (==) memeriksa apakah 10 sama dengan 20. Hasilnya False.
# 9. Operator tidak sama dengan (!=) memeriksa apakah 10 berbeda dengan 20. Hasilnya True.
# 10. Pada perbandingan berantai, 0 < 10 < 100 menghasilkan True karena 10 berada di antara 0 dan 100.
# 11. 0 < 20 < 100 juga menghasilkan True karena 20 berada di antara 0 dan 100.
# 12. Dari program ini dapat dipahami bahwa hasil operator perbandingan berupa True jika pernyataannya benar dan False jika pernyataannya salah.

# %% [markdown]
# ### 2.2.3 Program "logika_2611533014.py"

# %%
#Buat file dengan nama logika_NIM.py
#Nama variabel ditambah 4 digit nim terakhir contoh : angka_1234
#Program ini menggunakan fungsi input()
#Program operator Logika dalam Python

#Masukkan nilai boolean
#Input tidak peka terhadap huruf besar dan kecil 
a1_3014 = input ("Input nilai boolean-1(True/False): "). strip().lower() == "true"
a2_3014 = input ("Input nilai boolean-2(True/False): "). strip().lower() == "true"

print("\nA1 =", a1_3014)
print("A2 =" , a2_3014)

#Konjugasi : bernilai True jika keduanya True
hasil_3014 = a1_3014 and a2_3014
print("\nKonjugasi (AND)")
print("A1_3014 and A2_3014 =", hasil_3014)

#Disjungsi: bernilai True jika salah satunya True
hasil_3014 = a1_3014 or a2_3014
print("\nDisjungsi (OR)")
print("A1_3014 or A2_3014 =", hasil_3014)

#Negasi A1_3014: membalik nilai A1_3014
hasil_3014 = not a1_3014
print("\nNegasi A1_3014 (NOT)", hasil_3014)
print("not A1_3014 =", hasil_3014)

#Negasi A2_3014: membalik nilai A2_3014
hasil_3014 = not a2_3014
print("\nNegasi A2_3014 (NOT)")
print("not A2_3014 =", hasil_3014)

#XOR: bernilai True jika kedua nilai berbeda
hasil_3014 = a1_3014 != a2_3014
print("\nDisjungsi Eksklusif (XOR)")
print("A1_3014 XOR A2_3014 =", hasil_3014)
# Out:
# A1 = True
# A2 = False
#
# Konjugasi (AND)
# A1_3014 and A2_3014 = False
#
# Disjungsi (OR)
# A1_3014 or A2_3014 = True
#
# Negasi A1_3014 (NOT) False
# not A1_3014 = False
#
# Negasi A2_3014 (NOT)
# not A2_3014 = True
#
# Disjungsi Eksklusif (XOR)
# A1_3014 XOR A2_3014 = True

# %% [markdown]
# **Penjelasan:**
# 1. Program meminta pengguna memasukkan dua nilai boolean, yaitu True atau False.
# 2. Nilai yang dimasukkan tidak membedakan huruf besar dan kecil karena menggunakan .lower().
# 3. Fungsi input() digunakan untuk menerima nilai dari pengguna, kemudian hasilnya diubah menjadi boolean.
# 4. Pada percobaan, dimasukkan:
# A1 = True
# A2 = False
# 5. Operator AND digunakan untuk menghasilkan True jika kedua nilai bernilai True. Hasil A1 and A2 adalah False.
# 6. Operator OR menghasilkan True jika salah satu nilai bernilai True. Hasil A1 or A2 adalah True.
# 7. Operator NOT digunakan untuk membalik nilai boolean:
# not A1 → False
# not A2 → True
# 8. Operator XOR pada program menggunakan !=, yang menghasilkan True jika kedua nilai berbeda. Karena A1 True dan A2 False, hasil XOR adalah True.
# 9. ogram ini menunjukkan bagaimana operator logika digunakan untuk mengolah dan menentukan hasil dari nilai True dan False.

# %% [markdown]
# ### 2.2.4 Program "assignment_2611533014.py"

# %%
#Buat file dengan assignment_NIM.py
#Nama variabel ditambah 4 digit nim terakhir contoh : angka_1234
# Program ini menggunakan fungsi input ()
#Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
#Program operator assignment dalam Python

angka1_3014 = int(input("Input angka-1: "))
angka2_3014 = int(input("Input angka-2: "))

print("\nNilai awal angka =", angka1_3014)
print("Nilai angka2 = ", angka2_3014)

#Assignment biasa
hasil_3014 = angka1_3014
print("\nAssignment biasa (=)")
print("Hasil =", hasil_3014)

#Assignment penambahan
hasil_3014 = angka1_3014
hasil_3014 += angka2_3014
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_3014)

#Assignment pengurangan
hasil_3014 = angka1_3014
hasil_3014 -= angka2_3014
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_3014)

#Assignment perkalian
hasil_3014 = angka1_3014
hasil_3014 *= angka2_3014
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_3014)

#Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_3014 !=0:
    hasil_3014 = angka1_3014
    hasil_3014 /= angka2_3014
    print("\nAssignment pembagian (/=)")
    print("hasil =", hasil_3014)
    #Operator tambahan
    hasil_3014 = angka1_3014
    hasil_3014 //= angka2_3014
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil = ", hasil_3014)
    hasil_3014 = angka1_3014
    hasil_3014 %= angka2_3014
    print("\nAssignment sisa bagi (%=) ")
    print("hasil =", hasil_3014)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

#operator tambahan: assignment perpangkatan 
hasil_3014 = angka1_3014
hasil_3014 **= angka2_3014
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_3014)
# Out:
# Nilai awal angka = 10
# Nilai angka2 =  20
#
# Assignment biasa (=)
# Hasil = 10
#
# Assignment penambahan (+=)
# Hasil = 30
#
# Assignment pengurangan (-=)
# Hasil = -10
#
# Assignment perkalian (*=)
# Hasil = 200
#
# Assignment pembagian (/=)
# hasil = 0.5
#
# Assignment pembagian bulat (//=)
# Hasil =  0
#
# Assignment sisa bagi (%=)
# hasil = 10
#
# Assignment perpangkatan (**=)
# Hasil = 100000000000000000000

# %% [markdown]
# **Penjelasan:**
# 1. Program meminta pengguna memasukkan dua angka menggunakan fungsi input().
# 2. Nilai yang dimasukkan dikonversi menjadi tipe data integer menggunakan int().
# 3. Pada percobaan ini, nilai yang dimasukkan adalah:
# angka1 = 10
# angka2 = 20
# 4. Assignment biasa (=) memberikan nilai angka1 ke variabel hasil. Hasilnya 10.
# 5. Assignment penambahan (+=) menambahkan angka2 ke angka1. Hasilnya 10 + 20 = 30.
# 6. Assignment pengurangan (-=) mengurangi angka1 dengan angka2. Hasilnya 10 - 20 = -10.
# 7. Assignment perkalian (*=) mengalikan angka1 dengan angka2. Hasilnya 10 × 20 = 200.
# 8. Assignment pembagian (/=) membagi angka1 dengan angka2. Hasilnya 10 ÷ 20 = 0.5.
# 9. Assignment pembagian bulat (//=) menghasilkan pembagian tanpa angka desimal. Hasilnya 10 // 20 = 0.
# 10. Assignment sisa bagi (%=) mencari sisa dari pembagian 10 dengan 20. Hasilnya 10 % 20 = 10.
# 11. Assignment perpangkatan (**=) menghitung 10 pangkat 20. Hasilnya adalah 10²⁰ atau 100000000000000000000.
# 12. Bagian if angka2_3014 != 0 dDariigunakan untuk memastikan angka kedua tidak bernilai 0 sebelum melakukan operasi pembagian.

# %% [markdown]
# ### 2.2.5 Program "lainnya_2611533014.py"

# %%
#Buat file dengan nama lainnya_NIM.py
#Nama variabel ditambah 4 digit NIM terakhir contoh_1234
#Program ini menggunakan fungsi input()
#Program operator keanggotaan dan identitas

print("===============================")
print("1. OPERATOR KEANGGOTAAN")
print("===============================")

#Input beberapa data yang dipisahkan dengan koma
input_data_3014 = input("Masukkan beberapa angka,pisahkan dengan koma: ")

#Mengubah input menjadi list integer
data_3014 = [int(angka.strip()) for angka in input_data_3014.split(",")]

nilai_dicari_3014 = int(input("Masukkan angka yang ingin dicari: "))

#Operator in
hasil_3014 = nilai_dicari_3014 in data_3014
print("\nOperator keanggotaan IN")
print(nilai_dicari_3014, "in", data_3014, "=", hasil_3014)

#Operator not in
hasil_3014 = nilai_dicari_3014 not in data_3014
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_3014, "not in", data_3014, "=", hasil_3014)


print("\n==================================")
print("2. OPERATOR IDENTITAS")
print("===================================")

#objek1 menggunakan list dari input pengguna
objek1_3014 = data_3014

#objek2 merujuk pada objek yang sama dengan objek1
objek2_3014 = objek1_3014

#objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_3014 = data_3014.copy()

print("objek1 =", objek1_3014)
print("objek2 =", objek2_3014)
print("objek3 =", objek3_3014)

#Operator is
hasil_3014 = objek1_3014 is objek2_3014
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil_3014)

#Operator is not
hasil_3014 = objek1_3014 is not objek3_3014
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_3014)

#Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =", objek1_3014 is objek3_3014)
print("objek1 == objek3 =", objek1_3014 == objek3_3014)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan IN
# 30 in [10, 20, 30, 40] = True
#
# Operator keanggotaan NOT IN
# 30 not in [10, 20, 30, 40] = False
#
# ...
# 2. OPERATOR IDENTITAS
# ...
# objek1 = [10, 20, 30, 40]
# objek2 = [10, 20, 30, 40]
# objek3 = [10, 20, 30, 40]
#
# Operator identitas IS
# objek1 is objek2 = True
#
# Operator identitas IS NOT
# objek1 is not objek3 = True
#
# Perbandingan identitas dan nilai
# objek1 is objek3 = False
# objek1 == objek3 = True

# %% [markdown]
# **Penjelasan:**
#
# 1.  Program meminta beberapa angka yang dipisahkan dengan koma menggunakan fungsi input().
# 2.  Pada percobaan ini, angka yang dimasukkan adalah 10, 20, 30, 40.
# 3.  Data tersebut kemudian diubah menjadi sebuah list integer, yaitu [10, 20, 30, 40].
# 4.  Pengguna kemudian memasukkan angka yang ingin dicari, yaitu 30.
#
# Operator Keanggotaan:
#
# 1.  Operator in digunakan untuk mengecek apakah angka 30 terdapat di dalam list. Karena 30 ada di dalam list, hasilnya True.
# 2.  Operator not in digunakan untuk mengecek apakah angka 30 tidak terdapat di dalam list. Karena 30 ada di dalam list, hasilnya False.
#
# Operator Identitas:
#
# * objek1_3014 mengambil data dari data_3014.
#
# * objek2_3014 dibuat dengan mengacu pada objek yang sama dengan objek1_3014, sehingga objek1 is objek2 menghasilkan True.
#
# * objek3_3014 dibuat menggunakan .copy() sehingga memiliki isi yang sama tetapi merupakan objek yang berbeda.
#
# * objek1 is not objek3 menghasilkan True karena keduanya merupakan objek yang berbeda.
#
# * objek1 is objek3 menghasilkan False karena identitas objeknya berbeda.
#
# * objek1 == objek3 menghasilkan True karena isi dari kedua list tersebut sama.
#
# * Dari program ini dapat dipahami bahwa operator keanggotaan digunakan untuk mengecek keberadaan suatu nilai dalam data, sedangkan operator identitas digunakan untuk membandingkan apakah dua variabel merujuk pada objek yang sama.

# %% [markdown]
# ### 2.2.6 Program "bitwise_2611533014.py"

# %%
#Buat file dengan nama Bitwise_NIM.py
#Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
#Program ini menggunakan fungsi input()

print("\n==================================")
print("3. OPERATOR BITWISE")
print("===================================")

angka1_3014 = int(input("Masukkan angka bitwise-1:"))
angka2_3014 = int(input("Masukkan angka bitwise-2:"))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1_3014 =", angka1_3014, "| biner =", bin(angka1_3014))
print("angka2_3014 =", angka2_3014, "| biner =", bin(angka2_3014))

#Bitwise AND
hasil_3014 = angka1_3014 & angka2_3014
print("\nBitwise AND (&)")
print("angka1_3014 & angka2_3014 =", hasil_3014)
print("Biner hasil =", bin(hasil_3014))
print("Biner hasil (8 bit) =", format(hasil_3014, '08b'))

#Bitwise OR
hasil_3014 = angka1_3014 | angka2_3014
print("\nBitwise OR (|)")
print("angka1_3014 | angka2_3014 =", hasil_3014)
print("Biner hasil =", bin(hasil_3014))
print("Biner hasil (8 bit) =", format(hasil_3014, '08b'))

#Bitwise XOR
hasil_3014 = angka1_3014 ^ angka2_3014
print("\nBitwise XOR (^)")
print("angka1_3014 ^ angka2_3014 =", hasil_3014)
print("Biner hasil =", bin(hasil_3014))
print("Biner hasil (8 bit) =", format(hasil_3014, '08b'))

#Bitwise NOT
hasil_3014 = ~angka1_3014
print("\nBitwise NOT (~)")
print("~angka1_3014 =", hasil_3014)
print("Biner hasil =", bin(hasil_3014))
print("Biner hasil (8 bit) =", format(hasil_3014, '08b'))

#Bitwise geser ke kiri
jumlah_geser_3014 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_3014 = angka1_3014 << jumlah_geser_3014
print("\nBitwise geser ke kiri (<<)")
print("angka1_3014 <<", jumlah_geser_3014, "=", hasil_3014)
print("Biner hasil =", bin(hasil_3014))
print("Biner hasil (8 bit) =", format(hasil_3014, '08b'))

#Bitwise geser kanan
hasil_3014 = angka1_3014 >> jumlah_geser_3014
print("\nBitwise geser kanan (>>)")
print(angka1_3014, ">>", jumlah_geser_3014, "=", hasil_3014)
print("Biner hasil =", bin(hasil_3014))
print("Biner hasil (8 bit) =", format(hasil_3014, "08b"))
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner
# angka1_3014 = 10 | biner = 0b1010
# angka2_3014 = 20 | biner = 0b10100
#
# Bitwise AND (&)
# angka1_3014 & angka2_3014 = 0
# Biner hasil = 0b0
# Biner hasil (8 bit) = 00000000
#
# Bitwise OR (|)
# angka1_3014 | angka2_3014 = 30
# Biner hasil = 0b11110
# Biner hasil (8 bit) = 00011110
#
# Bitwise XOR (^)
# angka1_3014 ^ angka2_3014 = 30
# Biner hasil = 0b11110
# Biner hasil (8 bit) = 00011110
#
# Bitwise NOT (~)
# ~angka1_3014 = -11
# Biner hasil = -0b1011
# Biner hasil (8 bit) = -0001011
#
# Bitwise geser ke kiri (<<)
# angka1_3014 << 2 = 40
# Biner hasil = 0b101000
# Biner hasil (8 bit) = 00101000
#
# Bitwise geser kanan (>>)
# 10 >> 2 = 2
# Biner hasil = 0b10
# Biner hasil (8 bit) = 00000010

# %% [markdown]
# 1. Program meminta dua angka dan jumlah pergeseran bit menggunakan fungsi input().
# 2. Pada percobaan ini, nilai yang dimasukkan:
# angka1 = 10
# angka2 = 20
# jumlah pergeseran = 2
# 3. Fungsi bin() digunakan untuk mengubah angka desimal menjadi bentuk biner.
# 4. Bitwise AND (&) membandingkan bit dari kedua angka. Hasil dari 10 & 20 adalah 0.
# 5. Bitwise OR (|) menghasilkan bit 1 jika salah satu bit bernilai 1. Hasil dari 10 | 20 adalah 30.
# 6. Bitwise XOR (^) menghasilkan bit 1 jika kedua bit berbeda. Hasil dari 10 ^ 20 adalah 30.
# 7. Bitwise NOT (~) membalik bit dari angka1. Hasil ~10 adalah -11.
# 8. Geser kiri (<<) menggeser bit angka1 sebanyak 2 posisi ke kiri. Hasil 10 << 2 adalah 40.
# 9. Geser kanan (>>) menggeser bit angka1 sebanyak 2 posisi ke kanan. Hasil 10 >> 2 adalah 2.
# 10. format(hasil_3014, '08b') digunakan untuk menampilkan hasil dalam bentuk biner 8 bit.
# Dari program ini dapat dipahami bahwa operator bitwise bekerja dengan mengolah nilai berdasarkan bit atau bentuk biner dari suatu bilangan.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :Sistem Simulasi Transaksi dan Validasi Akses Toko Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.**

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas3_2611533014"

# %% [markdown]
# b. Kode Program Driver "NamaDriver_NIM"

# %%
print("======================================")
print("       PROGRAM TRANSAKSI TOKO")
print("======================================")

# Input data pelanggan
nama_3014 = input("Nama pelanggan        : ")
status_3014 = input("Status (member/biasa) : ").lower()
harga_3014 = float(input("Harga barang          : Rp"))
jumlah_3014 = int(input("Jumlah barang         : "))
promo_3014 = input("Kode promo            : ").upper()

# Kumpulan kode promo
kode_promo_3014 = ["DISKON7", "CERIA15", "BELANJA8"]

# ==========================================
# OPERATOR ARITMATIKA
# ==========================================

total_3014 = harga_3014 * jumlah_3014
rata_rata_3014 = total_3014 / jumlah_3014

# ==========================================
# OPERATOR PERBANDINGAN
# ==========================================

cek_belanja_3014 = total_3014 >= 100000
cek_jumlah_3014 = jumlah_3014 >= 3
cek_member_3014 = status_3014 == "member"

# ==========================================
# OPERATOR KEANGGOTAAN
# ==========================================

cek_promo_3014 = promo_3014 in kode_promo_3014

# ==========================================
# OPERATOR LOGIKA
# ==========================================

dapat_diskon_3014 = cek_member_3014 and cek_belanja_3014
dapat_promo_3014 = cek_promo_3014 and cek_jumlah_3014
akses_toko_3014 = cek_member_3014 or cek_belanja_3014
bukan_member_3014 = not cek_member_3014

# Menghitung diskon
if dapat_diskon_3014:
    diskon_3014 = total_3014 * 10 / 100
else:
    diskon_3014 = 0

total_bayar_3014 = total_3014 - diskon_3014

# ==========================================
# OPERATOR PENUGASAN
# ==========================================

poin_3014 = 0
poin_3014 += jumlah_3014

# ==========================================
# OPERATOR IDENTITAS
# ==========================================

promo_utama_3014 = kode_promo_3014
promo_salinan_3014 = kode_promo_3014.copy()

cek_identitas_3014 = promo_utama_3014 is kode_promo_3014
cek_beda_3014 = promo_utama_3014 is not promo_salinan_3014

# ==========================================
# OPERATOR BITWISE
# ==========================================

kode_akses_3014 = 0

# 0001 = member
if cek_member_3014:
    kode_akses_3014 |= 1

# 0010 = belanja minimal
if cek_belanja_3014:
    kode_akses_3014 |= 2

# 0100 = jumlah barang cukup
if cek_jumlah_3014:
    kode_akses_3014 |= 4

# 1000 = promo tersedia
if cek_promo_3014:
    kode_akses_3014 |= 8

# AND
cek_member_bit_3014 = kode_akses_3014 & 1
cek_promo_bit_3014 = kode_akses_3014 & 8

# XOR
kode_referensi_3014 = 9
hasil_xor_3014 = kode_akses_3014 ^ kode_referensi_3014

# Shift kiri
hasil_shift_3014 = kode_akses_3014 << 1

# ==========================================
# HASIL PROGRAM
# ==========================================

print("\n======================================")
print("          DATA TRANSAKSI")
print("======================================")

print("Nama pelanggan   :", nama_3014)
print("Status pelanggan :", status_3014)
print("Harga barang     : Rp", harga_3014)
print("Jumlah barang    :", jumlah_3014)
print("Kode promo       :", promo_3014)

print("\n------------ VALIDASI ------------")
print("Belanja >= 100000 :", cek_belanja_3014)
print("Jumlah >= 3       :", cek_jumlah_3014)
print("Status member     :", cek_member_3014)
print("Promo tersedia    :", cek_promo_3014)
print("Dapat diskon      :", dapat_diskon_3014)
print("Dapat promo       :", dapat_promo_3014)

print("\n---------- PERHITUNGAN ----------")
print("Total belanja     : Rp", total_3014)
print("Diskon            : Rp", diskon_3014)
print("Total pembayaran  : Rp", total_bayar_3014)
print("Rata-rata harga   : Rp", rata_rata_3014)

print("\n--------- HAK AKSES ---------")
print("Akses toko        :", akses_toko_3014)
print("Bukan member      :", bukan_member_3014)
print("Poin pelanggan    :", poin_3014)

print("\n--------- IDENTITAS ---------")
print("Identitas sama    :", cek_identitas_3014)
print("Identitas berbeda :", cek_beda_3014)

print("\n--------- BITWISE ---------")
print("Kode biner        :", format(kode_akses_3014, "04b"))
print("Kode desimal      :", kode_akses_3014)

print("\nCek member")
print(format(kode_akses_3014, "04b"), "& 0001")
print("Hasil             :", format(cek_member_bit_3014, "04b"))
print("Desimal           :", cek_member_bit_3014)

print("\nCek promo")
print(format(kode_akses_3014, "04b"), "& 1000")
print("Hasil             :", format(cek_promo_bit_3014, "04b"))
print("Desimal           :", cek_promo_bit_3014)

print("\nXOR")
print(format(kode_akses_3014, "04b"), "^", format(kode_referensi_3014, "04b"))
print("Hasil             :", format(hasil_xor_3014, "04b"))
print("Desimal           :", hasil_xor_3014)

print("\nSHIFT LEFT")
print(format(kode_akses_3014, "04b"), "<< 1")
print("Hasil             :", format(hasil_shift_3014, "b"))
print("Desimal           :", hasil_shift_3014)

print("\n======================================")
print("             SELESAI")
print("======================================")
# Out:
# ...
#        PROGRAM TRANSAKSI TOKO
# ...
#
# ...
#           DATA TRANSAKSI
# ...
# Nama pelanggan   : Nabila
# Status pelanggan : member
# Harga barang     : Rp 50000.0
# Jumlah barang    : 4
# Kode promo       : DISKON7
#
# ------------ VALIDASI ------------
# Belanja >= 100000 : True
# Jumlah >= 3       : True
# Status member     : True
# Promo tersedia    : True
# Dapat diskon      : True
# Dapat promo       : True
#
# ---------- PERHITUNGAN ----------
# Total belanja     : Rp 200000.0
# Diskon            : Rp 20000.0
# Total pembayaran  : Rp 180000.0
# Rata-rata harga   : Rp 50000.0
#
# --------- HAK AKSES ---------
# Akses toko        : True
# Bukan member      : False
# Poin pelanggan    : 4
#
# --------- IDENTITAS ---------
# Identitas sama    : True
# Identitas berbeda : True
#
# --------- BITWISE ---------
# Kode biner        : 1111
# Kode desimal      : 15
#
# Cek member
# 1111 & 0001
# Hasil             : 0001
# Desimal           : 1
#
# Cek promo
# 1111 & 1000
# Hasil             : 1000
# ...

# %% [markdown]
# **PENJELASAN:**
#
# **1. Jelaskan operator aritmatika yang digunakan dalam program dan fungsi masing-masing dalam proses transaksi.**
#
# Jawaban:
# Operator aritmatika yang digunakan yaitu perkalian (*), pembagian (/), dan pengurangan (-). Perkalian digunakan untuk menghitung total harga berdasarkan harga barang dan jumlah barang. Pembagian digunakan untuk menghitung harga rata-rata barang, sedangkan pengurangan digunakan untuk menghitung total pembayaran setelah dikurangi diskon.
#
# **2. Apa perbedaan penggunaan operator and, or, dan not pada program?**
#
# Jawaban:
# Operator and digunakan ketika dua kondisi harus terpenuhi, contohnya pelanggan harus member dan belanja minimal Rp100.000 untuk mendapatkan diskon. Operator or digunakan ketika salah satu kondisi sudah terpenuhi, misalnya pelanggan member atau memenuhi jumlah belanja tertentu. Sedangkan not digunakan untuk membalik nilai kondisi True menjadi False atau sebaliknya.
#
# **3. Bagaimana operator in dan not in digunakan untuk memeriksa kode promo?**
#
# Jawaban:
# Operator in digunakan untuk mengecek apakah kode promo yang dimasukkan pelanggan terdapat dalam daftar promo. Jika kode tersebut ada, hasilnya True. Operator not in digunakan untuk mengecek apakah kode promo tidak terdapat dalam daftar.
#
# **4. Apa perbedaan operator is dengan == pada Python?**
#
# Jawaban:
# Operator == digunakan untuk membandingkan nilai atau isi dari dua objek. Sedangkan is digunakan untuk mengecek apakah dua variabel menunjuk pada objek yang sama. Jadi, == membandingkan nilai, sedangkan is membandingkan identitas objek.
#
# **5. Bagaimana operator bitwise digunakan untuk menentukan hak akses pelanggan?**
#
# Jawaban:
# Operator bitwise digunakan dengan memberikan nilai bit tertentu untuk setiap kondisi pelanggan. Misalnya 0001 untuk member, 0010 untuk belanja minimal, 0100 untuk jumlah barang yang memenuhi syarat, dan 1000 untuk promo yang tersedia. Operator bitwise kemudian digunakan untuk menggabungkan dan memeriksa kondisi tersebut sehingga terbentuk kode akses pelanggan.
#
# **6. Jelaskan urutan proses program dari memasukkan data sampai mendapatkan hasil transaksi dan status promo.**
#
# Jawaban:
# Pertama, pelanggan memasukkan nama, status, harga barang, jumlah barang, dan kode promo. Setelah itu program menghitung total belanja. Selanjutnya program memeriksa status member, jumlah barang, batas belanja, dan ketersediaan promo. Dari hasil pemeriksaan tersebut program menentukan apakah pelanggan mendapatkan diskon dan promo. Jika mendapatkan diskon, program menghitung total pembayaran setelah diskon. Terakhir, program menampilkan hasil transaksi, hak akses, dan operasi bitwise.
#
# **7. Berikan contoh kondisi yang menghasilkan nilai True dan False dalam program?**
#
# Jawaban:
# Contoh kondisi yang menghasilkan True adalah cek_member_3014 ketika pelanggan memasukkan status member. Contoh kondisi yang menghasilkan False adalah bukan_member_3014 karena pelanggan tersebut merupakan member. Nilai tersebut menunjukkan bahwa hasil operator logika dapat berubah sesuai dengan data yang dimasukkan.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa operator merupakan bagian penting dalam pemrograman Python karena digunakan untuk mengolah data dan menentukan suatu kondisi. Python memiliki berbagai jenis operator, seperti operator aritmatika untuk melakukan perhitungan, operator perbandingan untuk membandingkan nilai, operator logika untuk menggabungkan kondisi, serta operator penugasan untuk memberikan atau mengubah nilai variabel. Selain itu, terdapat operator keanggotaan untuk memeriksa suatu nilai dalam data, operator identitas untuk membandingkan objek, dan operator bitwise untuk melakukan operasi pada bilangan dalam bentuk biner. Dengan memahami berbagai operator tersebut, kita dapat membuat program yang lebih terstruktur dan mampu melakukan proses sesuai dengan kondisi yang diberikan.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, "Operator — Standard Operators as Functions," Python Documentation, [2026]. [Online]. Tersedia: https://docs.python.org/id/3/library/operator.html [Diakses 19 September 2026].
#
# [2] Python Software Foundation, "Referensi Bahasa Python," Python Documentation, [2026]. [Online]. Tersedia: https://docs.python.org/id/3/reference/ [Diakses 19 September 2026].
#
# [3] Python Software Foundation, "Tipe Bawaan — Perbandingan dan Operasi Boolean," Python Documentation, [2026]. [Online]. Tersedia: https://docs.python.org/id/3.13/library/stdtypes.html [Diakses 19 September 2026].
